# %%
import fastf1 as ff1
from fastf1 import plotting
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd

# %%
session = ff1.get_session(2020, 1, 'R')
session.load()
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Fixed incorrect tyre stint information for driver '99'
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']

# %%
pd.DataFrame(session.session_info)
# Out:
#                                                         Meeting SessionStatus  \
# Key                                                        1279      Inactive
# Name                                      Australian Grand Prix      Inactive
# OfficialName  FORMULA 1 QATAR AIRWAYS AUSTRALIAN GRAND PRIX ...      Inactive
# Location                                              Melbourne      Inactive
# Number                                                        1      Inactive
# Country          {'Key': 5, 'Code': 'AUS', 'Name': 'Australia'}      Inactive
# Circuit                   {'Key': 10, 'ShortName': 'Melbourne'}      Inactive
# Status                                                      NaN      Inactive
#
#              ArchiveStatus    Key  Type  Name           StartDate  \
# Key                    NaN  11234  Race  Race 2026-03-08 15:00:00
# Name                   NaN  11234  Race  Race 2026-03-08 15:00:00
# OfficialName           NaN  11234  Race  Race 2026-03-08 15:00:00
# Location               NaN  11234  Race  Race 2026-03-08 15:00:00
# Number                 NaN  11234  Race  Race 2026-03-08 15:00:00
# Country                NaN  11234  Race  Race 2026-03-08 15:00:00
# Circuit                NaN  11234  Race  Race 2026-03-08 15:00:00
# Status          Generating  11234  Race  Race 2026-03-08 15:00:00
#
#                          EndDate       GmtOffset  \
# Key          2026-03-08 17:00:00 0 days 11:00:00
# Name         2026-03-08 17:00:00 0 days 11:00:00
# OfficialName 2026-03-08 17:00:00 0 days 11:00:00
# Location     2026-03-08 17:00:00 0 days 11:00:00
# Number       2026-03-08 17:00:00 0 days 11:00:00
# Country      2026-03-08 17:00:00 0 days 11:00:00
# Circuit      2026-03-08 17:00:00 0 days 11:00:00
# Status       2026-03-08 17:00:00 0 days 11:00:00
#
#                                                            Path
# Key           2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Name          2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# OfficialName  2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Location      2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Number        2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Country       2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Circuit       2026/2026-03-08_Australian_Grand_Prix/2026-03-...
# Status        2026/2026-03-08_Australian_Grand_Prix/2026-03-...

# %%
pd.DataFrame(session.weather_data)
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0   0 days 00:00:13.466000     23.1      55.8    1013.7     False       36.2
# 1   0 days 00:01:13.482000     23.2      55.1    1013.6     False       35.9
# 2   0 days 00:02:13.483000     23.2      55.2    1013.6     False       35.6
# 3   0 days 00:03:13.485000     23.1      55.7    1013.7     False       35.7
# 4   0 days 00:04:13.518000     23.1      55.8    1013.8     False       35.8
# ..                     ...      ...       ...       ...       ...        ...
# 143 0 days 02:23:14.291000     25.2      51.9    1011.5     False       34.6
# 144 0 days 02:24:14.277000     25.2      52.0    1011.5     False       34.4
# 145 0 days 02:25:14.290000     25.1      51.7    1011.5     False       34.5
# 146 0 days 02:26:14.290000     25.0      52.2    1011.5     False       34.3
# 147 0 days 02:27:14.318000     25.0      52.7    1011.5     False       34.5
#
#      WindDirection  WindSpeed
# 0              114        1.8
# 1              110        3.0
# 2              115        3.2
# 3              104        3.4
# 4              108        3.1
# ..             ...        ...
# 143            127        3.7
# 144            105        2.9
# 145            103        2.9
# 146            114        2.5
# 147            117        1.9
#
# [148 rows x 8 columns]

# %%
pd.DataFrame(session.race_control_messages)
# Out:
#                    Time Category  \
# 0   2026-03-08 03:08:08    Other
# 1   2026-03-08 03:20:00     Flag
# 2   2026-03-08 03:21:22     Flag
# 3   2026-03-08 03:21:25     Flag
# 4   2026-03-08 03:21:26     Flag
# ..                  ...      ...
# 162 2026-03-08 05:26:19     Flag
# 163 2026-03-08 05:26:33     Flag
# 164 2026-03-08 05:29:56    Other
# 165 2026-03-08 05:32:13     Flag
# 166 2026-03-08 05:33:37     Flag
#
#                                                Message Status           Flag  \
# 0              PINK HEAD PADDING MATERIAL MUST BE USED   None           None
# 1                          GREEN LIGHT - PIT EXIT OPEN   None          GREEN
# 2                      DOUBLE YELLOW IN TRACK SECTOR 6   None  DOUBLE YELLOW
# 3                              CLEAR IN TRACK SECTOR 6   None          CLEAR
# 4                             YELLOW IN TRACK SECTOR 7   None         YELLOW
# ..                                                 ...    ...            ...
# 162  WAVED BLUE FLAG FOR CAR 11 (PER) TIMED AT 16:2...   None           BLUE
# 163                                     CHEQUERED FLAG   None      CHEQUERED
# 164           ALL PASS HOLDERS MAY ACCESS THE PIT LANE   None           None
# 165                   DOUBLE YELLOW IN TRACK SECTOR 19   None  DOUBLE YELLOW
# 166                           CLEAR IN TRACK SECTOR 19   None          CLEAR
#
#       Scope  Sector RacingNumber  Lap
# 0      None     NaN         None    0
# 1     Track     NaN         None    1
# 2    Sector     6.0         None    1
# 3    Sector     6.0         None    1
# 4    Sector     7.0         None    1
# ..      ...     ...          ...  ...
# 162  Driver     NaN           11   58
# 163   Track     NaN         None   58
# 164    None     NaN         None   58
# 165  Sector    19.0         None   58
# 166  Sector    19.0         None   58
#
# [167 rows x 9 columns]

# %%
import json
pd.json_normalize(session.car_data, depth)

# %%
session = ff1.get_session(2026, 4, 'R')
session.load()
fastest_lap = session.laps.pick_fastest()

# use padding so that there are values outside of the desired range for accurate interpolation later
car_data = fastest_lap.get_car_data(pad=1, pad_side='both')
pos_data = fastest_lap.get_pos_data(pad=1, pad_side='both')

# do calculations here
# ...
# ...

merged_data = car_data.merge_channels(pos_data)

# slice again to remove the padding and interpolate the exact first and last value
merged_data = merged_data.slice_by_lap(fastest_lap, interpolate_edges=True)

# %%
merged_data

# %%
import matplotlib.pyplot as plt
plt.hist(x=df['DRS'], y=df['count'])
df.info()

# %%
df = pd.DataFrame(merged_data['DRS'].value_counts()).reset_index()

# %%
df.shape

# %%
df
